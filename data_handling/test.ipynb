# %%
import pandas as pd

df = pd.read_csv('cancer.csv')

# drop last column
df.drop(df.columns[-1], axis=1, inplace=True)
df.dropna(inplace=True)

# rename column diagnosis to malignant
df.rename(columns={'diagnosis': 'malignant'}, inplace=True)

# convert malignant to 0 and 1
df['malignant'] = df['malignant'].map({'M': 1, 'B': 0})

# drop id column
df.drop('id', axis=1, inplace=True)

# take 500 rows of data randomly
df = df.sample(n=500, random_state=1)

# count malignant and benign
print(df['malignant'].value_counts())

df.reset_index(drop=True, inplace=True)

# save to data.csv
df.to_csv('data.csv', index=False)
# Out:
# 0    315
# 1    185
# Name: malignant, dtype: int64

# %%
df = pd.read_csv('data.csv')

df.head()
# Out:
#    malignant  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0          0        14.69         13.98           98.22      656.1
# 1          1        13.17         18.66           85.98      534.6
# 2          0        12.95         16.02           83.14      513.7
# 3          1        18.31         18.58          118.60     1041.0
# 4          1        15.13         29.81           96.71      719.5
#
#    smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# 0          0.10310           0.18360         0.14500              0.06300
# 1          0.11580           0.12310         0.12260              0.07340
# 2          0.10050           0.07943         0.06155              0.03370
# 3          0.08588           0.08468         0.08169              0.05814
# 4          0.08320           0.04605         0.04686              0.02739
#
#    symmetry_mean  ...  radius_worst  texture_worst  perimeter_worst  \
# ...
